# %% [markdown]
# # Weeks 7: Data as Data, Part 1
#
# <img src="https://images.unsplash.com/photo-1545987796-200677ee1011?auto=format&fit=crop&q=80&w=2070&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D" width="750" height="540">
#
#
# Now that we have been working with text as data to develop and hone our data organization and data visualization skills, we will turn our attention to data that is more transparently quantitative in nature. After some initial work in Excel and/or Google Sheets, we will return to our old friend, R.
#
#
# ## Chunk 1- Data Analysis/Visualization in Excel and Google Sheets
#
# Spreadsheet software tools, like Excel and Google Sheets, are very commonly used for all kinds of data analysis and visualization. In my own work life, as opposed to my research life, I use spreadsheets for these purposes a great deal. So, we will use these first two chunks to explore these spreadsheet tools.
#
# ### Chunk 1: Excel
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/45/Screen-calc-spreadsheet-physics-simulation-elementary-iconset.jpg" width="650" height="340">
#
#
# Here is the work for this Chunk:
#
# 1. *Exploration*. The folks at [Data Camp](https://www.datacamp.com/) have put together a really good tutorial for doing basic (and some advanced) data analysis and data visualization tasks using Excel. You can find this tutorial [here](https://www.datacamp.com/tutorial/visualizing-data-in-excel). Please through all of the components of this tutorial.
#
# 2. *Sharing*. Please be sure to collect artifacts of your work in Google Sheets, along with a reflection that discusses the work you have done there.
#
#
# Note: If you do not own Excel, you have access to via your Mville login credentials. You can access Office 365 [here](https://www.mville.edu/current_students.php).
#
#
#
# ### Chunk 2: Google Sheets
#
# <img src="https://i.ytimg.com/vi/4rlQc6Ckujs/maxresdefault.jpg" width="650" height="340">
#
# As I am sure you know, lots of schools and school districts use Google tools, and so it makes sense to gain some proficiency in doing some basic data analysis and data visualization work in Google Sheets.
#
#
# Here is the work for this Chunk:
#
# 1. *Exploration*. The folks at Google have put together a really good tutorial for doing basic (and some advanced) data analysis and data visualization tasks using Google Sheets [here](https://support.google.com/a/users/answer/13189180?hl=en&ref_topic=9296611&sjid=1804006885521859299-NA). Please through all ten of the components of this tutorial.
#
# 2. *Sharing*. Please be sure to collect artifacts of your work in Google Sheets, along with a reflection that discusses the work you have done there.
#
#
#
#
# ###  Chunk 3: Applying What You Have Learned
#
#
#
# <img src="https://images.unsplash.com/photo-1596495718166-7ac739ca1bc4?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&auto=format&fit=crop&w=2071&q=80" width="650" height="340">
#
# #### Showing What You Know
#
# Now that you have acquired some data analysis and visualization skills in these two spreadsheet programs, it is time for you to take this skills for a test drive. For this test drive, we will use some education focused data.
#
# For this work, please go to the [New York State Department of Education Data website](https://data.nysed.gov/). Take a look at the datasets available, and pick one of interest to you.
#
# Once you have done these analyses, please gather your methods and findings into a short paper (including visualizations).
#
#
#
# ### Posting Reflections and Visualizations
#
# <img src="https://i.imgur.com/2fTqBpU.jpeg" width="650" height="340">
#
# You will continue share your analysis and reflections using the same document you began for the Week 1 work. Be as generous as you can with your sharing -- show pictures, notes, etc.
#
# Now that you are set up in Slack, please share your reflections on the texts and your data analysis and visualization work in the #learining-about-data-and-education channel.
#
# Feel free to respond to one another and/or ask questions there as well.
#
# **You have one week to complete this work. This work is due by Monday, October 30, end of day.**
